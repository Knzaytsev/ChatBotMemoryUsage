# %%
# !pip install torch
# !pip install transformers
# !pip install SentencePiece
# !pip install accelerate

# %%
from string import Template
from sentencepiece import SentencePieceProcessor
from logging import getLogger
from typing import List
import os
import torch
from transformers import AutoTokenizer, AutoModelForCausalLM


logger = getLogger()


class Tokenizer:
    def __init__(self, model_path: str):
        # reload tokenizer
        assert os.path.isfile(model_path), model_path
        self.sp_model = SentencePieceProcessor(model_file=model_path)
        logger.info(f"Reloaded SentencePiece model from {model_path}")

        # BOS / EOS token IDs
        self.n_words: int = self.sp_model.vocab_size()
        self.bos_id: int = self.sp_model.bos_id()
        self.eos_id: int = self.sp_model.eos_id()
        self.pad_id: int = self.sp_model.pad_id()
        logger.info(
            f"#words: {self.n_words} - BOS ID: {self.bos_id} - EOS ID: {self.eos_id}"
        )
        assert self.sp_model.vocab_size() == self.sp_model.get_piece_size()

    def encode(self, s: str, bos: bool, eos: bool) -> List[int]:
        assert type(s) is str
        t = self.sp_model.encode(s)
        if bos:
            t = [self.bos_id] + t
        if eos:
            t = t + [self.eos_id]
        return t

    def decode(self, t: List[int]) -> str:
        return self.sp_model.decode(t)

# %%
# from transformers import AutoTokenizer, AutoModelForCausalLM

# tokenizer = AutoTokenizer.from_pretrained("eachadea/vicuna-7b-1.1")

# model = AutoModelForCausalLM.from_pretrained("eachadea/vicuna-7b-1.1")

# %%
tokenizer = Tokenizer('./LLaMA_tokenizer.model')

model = AutoModelForCausalLM.from_pretrained("eachadea/vicuna-7b-1.1", device_map='auto')
# Out:
# Downloading (…)lve/main/config.json:   0%|          | 0.00/554 [00:00<?, ?B/s]
# Downloading (…)model.bin.index.json:   0%|          | 0.00/26.8k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/2 [00:00<?, ?it/s]
# Downloading (…)l-00001-of-00002.bin:   0%|          | 0.00/9.98G [00:00<?, ?B/s]
# Downloading (…)l-00002-of-00002.bin:   0%|          | 0.00/3.50G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# Downloading (…)neration_config.json:   0%|          | 0.00/137 [00:00<?, ?B/s]

# %%
def gen_answer(model, tokenizer, prompt, subs):
    input_text = prompt.substitute(**subs)
    
    conv = Conversation(
                system="A chat between a curious user and an artificial intelligence assistant. "
                "The assistant gives helpful, detailed, and polite answers to the user's questions.",
                roles=("USER", "ASSISTANT"),
                messages=[],
                offset=0,
                sep_style=SeparatorStyle.TWO,
                sep=" ",
                sep2="</s>",
            )
    
    conv.append_message("USER", input_text)
    conv.append_message("ASSISTANT", None)
    
    input_text = conv.get_prompt()
    
    tokenized_input_text = torch.tensor([tokenizer.encode(input_text, False, False)]).to(0)
    
    generated_indices = model.generate(input_ids=tokenized_input_text, max_new_tokens=512, 
                                       temperature=.7, do_sample=True).detach().cpu()
    facts = tokenizer.decode(generated_indices[0].tolist())
    
    prompt_result = facts[len(input_text):]
    
    return prompt_result

# %%
def gen_speakers_facts(**kwargs):
    speakers = kwargs['speakers']
    dialog = kwargs['dialog']
    prompt = kwargs['prompt']

    speakers_facts = dict()
    for speaker in speakers:
        speakers_facts[speaker] = gen_answer(model, tokenizer, prompt, 
                                             {'speaker': speaker, 'dialog': dialog})
    return speakers_facts

# %%
def gen_summarization(**kwargs):
    dialog = kwargs['dialog']
    prompt = kwargs['prompt']

    summarization = {'Summarization': gen_answer(model, tokenizer, prompt, {'dialog': dialog})}
    return summarization

# %%
prompts = {
    'facts': {
        'prompt':
        Template("""$dialog\nPlease, write only relevant facts about $speaker in number list."""),
        'method': gen_speakers_facts
    },
    'summarization': {
        'prompt':
        Template('$dialog\nProvide a summary of the exchange between bot_0 and bot_1.'),
        'method': gen_summarization
    }
}

# %%
import json

with open('./sample_data_summ_sess.json', 'r') as f:
    dialogs = json.loads(f.read())

speakers = ['bot_0', 'bot_1']

# %%
import dataclasses
from enum import auto, Enum
from typing import List, Tuple, Any


class SeparatorStyle(Enum):
    """Different separator style."""

    SINGLE = auto()
    TWO = auto()
    DOLLY = auto()
    OASST_PYTHIA = auto()


@dataclasses.dataclass
class Conversation:
    """A class that keeps all conversation history."""

    system: str
    roles: List[str]
    messages: List[List[str]]
    offset: int
    sep_style: SeparatorStyle = SeparatorStyle.SINGLE
    sep: str = "###"
    sep2: str = None

    # Used for gradio server
    skip_next: bool = False
    conv_id: Any = None

    def get_prompt(self):
        if self.sep_style == SeparatorStyle.SINGLE:
            ret = self.system
            for role, message in self.messages:
                if message:
                    ret += self.sep + " " + role + ": " + message
                else:
                    ret += self.sep + " " + role + ":"
            return ret
        elif self.sep_style == SeparatorStyle.TWO:
            seps = [self.sep, self.sep2]
            ret = self.system + seps[0]
            for i, (role, message) in enumerate(self.messages):
                if message:
                    ret += role + ": " + message + seps[i % 2]
                else:
                    ret += role + ":"
            return ret
        elif self.sep_style == SeparatorStyle.DOLLY:
            seps = [self.sep, self.sep2]
            ret = self.system
            for i, (role, message) in enumerate(self.messages):
                if message:
                    ret += role + ":\n" + message + seps[i % 2]
                    if i % 2 == 1:
                        ret += "\n\n"
                else:
                    ret += role + ":\n"
            return ret
        elif self.sep_style == SeparatorStyle.OASST_PYTHIA:
            ret = self.system
            for role, message in self.messages:
                if message:
                    ret += role + message + self.sep
                else:
                    ret += role
            return ret
        else:
            raise ValueError(f"Invalid style: {self.sep_style}")

    def append_message(self, role, message):
        self.messages.append([role, message])

    def to_gradio_chatbot(self):
        ret = []
        for i, (role, msg) in enumerate(self.messages[self.offset :]):
            if i % 2 == 0:
                ret.append([msg, None])
            else:
                ret[-1][-1] = msg
        return ret

    def copy(self):
        return Conversation(
            system=self.system,
            roles=self.roles,
            messages=[[x, y] for x, y in self.messages],
            offset=self.offset,
            sep_style=self.sep_style,
            sep=self.sep,
            sep2=self.sep2,
            conv_id=self.conv_id,
        )

    def dict(self):
        return {
            "system": self.system,
            "roles": self.roles,
            "messages": self.messages,
            "offset": self.offset,
            "sep": self.sep,
            "sep2": self.sep2,
            "conv_id": self.conv_id,
        }

# %%
torch.cuda.empty_cache()

# %%
from tqdm import tqdm
from os.path import exists

transform_txt_dialog = lambda x: x['id'] + ': ' + x['text']

stages = ['facts', 'summarization']

results = []

OUTPUT_PATH = f'./sess_outputs.json'
output_dialogs = list()
if exists(OUTPUT_PATH):
    with open(OUTPUT_PATH, 'r') as f:
        output_dialogs = json.loads(f.read())

start_position = len(output_dialogs)
print(start_position)
# Out:
# 55

# %%
for dialog in tqdm(dialogs[start_position:start_position+55]):
    for stage in stages:
        prompt = prompts[stage]['prompt']
        method = prompts[stage]['method']
        for session, sess_dialog in dialog.items():
            prompt_result = method(model=model, tokenizer=tokenizer, prompt=prompt, 
                                dialog='\n'.join(map(transform_txt_dialog, sess_dialog['dialog'])), 
                                speakers=speakers)
            sess_dialog[stage] = prompt_result
    
    output_dialogs.append(dialog)
    with open(OUTPUT_PATH, 'w') as f:
        json.dump(output_dialogs, f)
# Out:
#   5%|▌         | 3/55 [09:17<2:46:39, 192.29s/it]

# %%
dialog['session_1']['facts']
# Out:
# {'bot_0': ' * bot\\_0: mentioned enjoying the Archey Center and loving to go there every hour and kind of\n* bot\\_0: mentioned having a favorite singer\n* bot\\_0: asked if bot\\_1 likes to ride bikes\n* bot\\_1: responded that they do not like to ride bikes because it is too dangerous\n* bot\\_0: mentioned getting a new job\n* bot\\_0: mentioned cleaning gutters for a living\n* bot\\_1: mentioned sewing as a hobby to keep the voices at bay',
#  'bot_1': ' * bot\\_1 does not like to ride bikes\n* bot\\_1 is a male\n* bot\\_1 works as a waiter\n* bot\\_1 has a hobby of sewing which helps to keep the voices at bay.'}

# %%
500 // 9
# Out:
# 55

# %%
55 * 9
# Out:
# 495

# %%
20 / 10
# Out:
# 2.0

# %%
for s, d in dialog.items():
    print(s)
    print('\n'.join(map(transform_txt_dialog, d['dialog'])))
    print('\nfacts bot_0:')
    print(d['facts']['bot_0'])
    print('\nfacts bot_1:')
    print(d['facts']['bot_1'])
    print('\n', d['summarization']['Summarization'])
    print('-'*10)
# Out:
# session_1
# bot_0: Hey there how are you at this?
# bot_1: Well, hey yourself! I can handle myself. Are you shy?
# bot_0: You like the archey center? I love it
# bot_1: Heck, I never even heard of such a thing. Sounds sporty. Is it fun?
# bot_0: I love to go every hour an kind of, got a fav singer?
# bot_1: Not unless my cat counts as a singer. Who is yours?
# bot_0: Do you like to ride bikes?
# bot_1: Oh no. Too dangerous. My momma was a nurse and she warned me about that.
# bot_0: Really? I just got a new job
# bot_1: No kidding. I wait tables. What is it that you do?
# bot_0: I'll be cleaning gutters outside
# bot_1: Well, that's good honest work right there. What do you do for fun?
# bot_0: I like to ride my bike when I have time
# bot_1: Oh, right. You mentioned bikes earlier. I just sew. It keeps the voices at bay.
#
# facts bot_0:
#  * bot\_0: mentioned enjoying the Archey Center and loving to go there every hour and kind of
# * bot\_0: mentioned having a favorite singer
# * bot\_0: asked if bot\_1 likes to ride bikes
# * bot\_1: responded that they do not like to ride bikes because it is too dangerous
# * bot\_0: mentioned getting a new job
# * bot\_0: mentioned cleaning gutters for a living
# * bot\_1: mentioned sewing as a hobby to keep the voices at bay
#
# facts bot_1:
#  * bot\_1 does not like to ride bikes
# * bot\_1 is a male
# * bot\_1 works as a waiter
# * bot\_1 has a hobby of sewing which helps to keep the voices at bay.
#
#   In this exchange, bot\_0 and bot\_1 engage in small talk, with bot\_0 asking about the archey center and whether bot\_1 likes to ride bikes. Bot\_1 tells bot\_0 that they don't like to ride bikes because it's too dangerous and that they sew as a hobby to keep the voices at bay. Bot\_0 then asks if bot\_1 likes to go to the archey center, but bot\_1 is unfamiliar with the term. Bot\_0 reveals that they love to go to the archey center every hour and have a favorite singer, but bot\_1 is unsure if they have ever heard of such a thing. Bot\_0 also asks bot\_1 if they like to ride bikes, but bot\_1 responds that they don't due to safety concerns.
# ----------
# session_2
# bot_0: Did you play with your cat?
# bot_1: Yes i did, we went for a walk.
# bot_0: A walk? Where did you go? Does he stay calm outside?
# bot_1: We went to the park. yes a bit calm but not always.
# bot_0: That's so funny, what would you do if he climbed up a tree?
# bot_1: I wouldn't want to be that careless. It's gonna be tough if such happens.
# bot_0: I'd imagine you have a harness for him in that case. I've always thought about getting those for pets.
# bot_1: Yes that's the best, you should get one you know. It'd be great.
# bot_0: I'd feel a lot better using that rather than a collar! That's for sure. I hope the store nearby has them.
# bot_1: They should. I'm sure something like that shouldn't be hard to find.
# bot_0: I hope so I will look tomorrow, do they come with different patterns?
# bot_1: Yes different patterns. some you'd love a lot.
#
# facts bot_0:
#  bot_0:
#
# * Asks if bot_1 played with their cat
# * Learns that bot_1 went for a walk with their cat
# * Wonders if the cat stays calm during walks
# * Asks about what bot_1 would do if the cat climbed up a tree
# * Mentions the possibility of getting a harness for pets
# * Encourages bot_1 to get a harness for their cat
# * Wonders if the store nearby has harnesses
# * Hopes that the store has different patterns of harnesses.
#
# facts bot_1:
#  * bot_1 mentioned going for a walk with their cat
# * they mentioned that their cat was calm during the walk
# * bot_1 mentioned that they have a harness for their cat
# * they suggested that others should get a harness for their pets.
#
#   The exchange between bot\_0 and bot\_1 is about a cat named "he" who went for a walk with the speaker. They discuss that the cat stayed calm during the walk and they went to the park. They also talk about what would happen if the cat climbs up a tree, and the speaker mentions that they have a harness for the cat. The speaker also suggests that getting a harness is a good idea and that different patterns of harnesses are available.
# ----------
# session_3
# bot_0: I finally visited the pet store and bought nice harnesses for all my pets.
# bot_1: That's good, I'm glad you got that sorted. It will be good for them. Remind me what pets you have.
# bot_0: I have 2 dogs and a cat.  So now they're all ready to go for a walk.  Surprisingly, my cat actually walks with us sometimes.  Does your cat ever go outside?
# bot_1: Yeah, sometimes. We have a bit of land around our house so she goes prowling. Sometimes brings us some presents back.
# bot_0: Yuck, those cat presents are never fun.  I've gotten my fair share of those, haha!  What's your cat's name?
# bot_1: Phoebe. I love her to bits. How do the cat and the dogs get on?
# bot_0: Aww, that's a cute name.  They really do quite well together.  They're all like best buds.  They're really protective of each other though, so they're not always quick to warm up to other peoples pets.
# bot_1: That's understandable. That shows you must be taking real good care of them for them to be comfortable together. How is your work going?
# bot_0: It's going.  I don't know, it's fine I guess.  It gets monotonous cleaning gutters all day, but at least I can listen to music while I work. How about you? How's your job going lately?
# bot_1: Same really. It pays the bills. I like the fact I get to interact with people, but it's not what I'd love to do. I'd love to be a vet.
# bot_0: That's awesome. Do you have any plans to go to vet school?  I have a friend who finally became a vet, but it was a long, difficult journey.  I had never known that vet school is harder to get accepted into than med school.
# bot_1: I wish I could but I don't know if I could devote the time. I look at the the example of my mum and think everything she devoted to her work and wonder if I could do it.
#
# facts bot_0:
#  * bot_0 has 2 dogs and a cat
# * bot_0 bought harnesses for their pets
# * bot_0's cat walks with them
# * bot_1's cat goes outside
# * bot_1's cat's name is Phoebe
# * bot_0's cat and dogs get along well
# * bot_0's work is cleaning gutters
# * bot_1's job is interacting with people, but not their dream job
# * bot_1 wishes to become a vet but is unsure if they could devote the time.
#
# facts bot_1:
#  * bot_1 has a cat named Phoebe
# * They have a job that pays the bills and involves interaction with people
# * bot_1 is interested in becoming a vet
# * bot_1 is unsure if they could devote the time necessary for vet school.
#
#   The conversation between bot\_0 and bot\_1 revolves around their pets and work. bot\_0 visits a pet store and buys harnesses for their pets, which includes two dogs and a cat. bot\_1 is glad that bot\_0 got the pets' harnesses sorted, and bot\_1 reminds bot\_0 of the pets' names. bot\_0 mentions that their cat walks with them and sometimes brings presents back. bot\_1 shares that they have a cat named Phoebe and that they love her, but bot\_0 adds that cat presents can be yucky. bot\_1 asks about bot\_0's work, and bot\_0 replies that it's fine, but monotonous. bot\_1 shares that they also work, but they enjoy interacting with people, but it's not their dream job. bot\_0 asks if bot\_1 has plans to become a vet, and bot\_1 replies that they wish they could but aren't sure if they could devote the time. bot\_1 also mentions their mother as an example and wonders if they could do the same.
# ----------
